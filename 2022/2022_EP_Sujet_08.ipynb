# %% [markdown]
# <h1 class="alert alert-info">Sujet n°08 session 2022</h1>

# %% [markdown]
# <h1 class="alert alert-success">Exercice 1</h1>

# %% [markdown]
# Écrire une fonction <code>recherche</code> qui prend en paramètres <code>elt</code> un nombre entieret <code>tab</code> un tableau de nombres entiers, et qui renvoie l’indice de la première occurrence de <code>elt</code> dans <code>tab</code> si <code>elt</code> est dans <code>tab</code> et <code>-1</code> sinon.
#
# *Exemples:*
#
#     >>>recherche(1,[2,3,4])
#     -1
#     >>>recherche(1,[10,12,1,56])
#     2
#     >>>recherche(50,[1,50,1])
#     1
#     >>>recherche(15,[8,9,10,15])
#     3

# %%
def recherche(elt, tab):
    for i in range(len(tab)):
        if tab[i] == elt:
            return i
    return -1

# %%
recherche(1, [2,3,4])
# Out:
# -1

# %%
recherche(1, [10,12,1,56])
# Out:
# 2

# %%
recherche(15, [8,9,10,15])
# Out:
# 3

# %%
recherche(50, [1,50,1])
# Out:
# 1

# %% [markdown]
# <h1 class="alert alert-success">Exercice 2</h1>

# %% [markdown]
# On  considère  la  fonction <code>insere</code> ci-dessous  qui  prend  en  argument  un entier <code>a</code> et  un tableau <code>tab</code> d'entiers triés par ordre croissant. Cette fonction insère la valeur <code>a</code> dans le tableau et renvoie le nouveau tableau. Les tableaux seront représentés sous la forme de listes Python.
#
# Compléter la fonction <code>insere</code> ci-dessous.
#
# *Exemples:*
#
#     >>> insere(3,[1,2,4,5])
#     [1, 2, 3, 4, 5]
#     >>> insere(10,[1,2,7,12,14,25])
#     [1, 2, 7, 10, 12, 14, 25]
#     >>> insere(1,[2,3,4])
#     [1, 2, 3, 4]

# %%
def insere(a, tab):
    if len(tab) == 0:
        return [a]
    l = list(tab) # l contient les mêmes éléments que tab
    #L'élément à insérer est mis à la fin du tableau
    l.append(a)
    #On part donc de la fin du tableau, moins un pour éviter de dépasser
    i = len(tab)-1
    while a < tab[i] and i != -1: 
        #On s'arrête à -1 car sinon on ne peut pas placer un elt 
        #qui serait en premier dans l'ordre
        l[i+1] = l[i] #On décale
        l[i] = a #L'indice actuel devient notre valeur à insérer
        #Comme on est parti de la fin on décrémente
        i = i - 1
    return l

# %%
insere(3, [1,2,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
insere(10, [1,2,7,12,14,25])
# Out:
# [1, 2, 7, 10, 12, 14, 25]

# %%
insere(1, [2,3,4])
# Out:
# [1, 2, 3, 4]
